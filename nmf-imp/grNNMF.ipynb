# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF
from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics.pairwise import cosine_similarity as cosine
from scipy.sparse.csgraph import connected_components
import itertools
import json
import numpy as np
import glob

# %%
##generate data as array of strings from local .txt files
local_data = []
philes =  glob.glob("/Users/ziv/GDrive/school/math-thesis/nmf-imp/data/*.txt")
for phile in philes:
    with open(phile, 'r') as myfile:
        data=myfile.read().replace('\n', '')
        local_data.append(unicode(data, errors='ignore'))

# %%
#tfdif and nmf model building
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, #max_features=n_features,
                                   stop_words='english')
    
tfidf = tfidf_vectorizer.fit_transform(local_data)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
def generate_graphs(X,p):
    W_raw = np.zeros((X.shape[1],X.shape[1]))
    for i in range(0,X.shape[0]):
        for j in range(0,X.shape[0]):
            W_raw[i,j] = np.dot(X[i,], t(X[j,]))[0,0]
    s = W_raw.flatten()
    thresh = np.percentile(s,p)
    W = (W_raw > thresh).astype(int)
    D = np.zeros((X.shape[1],X.shape[1]))
    for i in range(0,X.shape[0]):
        D[i,i] = sum(W[i,])
    return W,D

# %%
def grnmf(X,k,lam,p,u0=None,v0=None):
    W,D = generate_graphs(X,p)
    if u0==None: 
        u = np.random.rand(X.shape[0],k)
    else:
        u = u0
    if v0==None:
        v = np.random.rand(X.shape[1],k)
    else:
        v = v0
    i = 0    
    while i < 1000:
        u = u = np.multiply(u,((X*v)/ np.dot(np.dot(u,t(v)),v)))
        v = np.multiply(v , ((np.dot(t(X),u) + 0.2*np.dot(W,v))/ (np.dot(np.dot(v,t(u)),u) + .2*np.dot(D,v))))
        i +=1
        if i % 5 ==0:
            print str(i) + "/1000 iterations complete"
    return u,v

# %%
def t(x):
    return np.transpose(x)

# %%
u,v = grnmf(X,k=10,lam=2,p=90)
# Out:
# 5/1000 iterations complete
# 10/1000 iterations complete
# 15/1000 iterations complete
# 20/1000 iterations complete
# 25/1000 iterations complete
# 30/1000 iterations complete
# 35/1000 iterations complete
# 40/1000 iterations complete
# 45/1000 iterations complete
# 50/1000 iterations complete
# 55/1000 iterations complete
# 60/1000 iterations complete
# 65/1000 iterations complete
# 70/1000 iterations complete
# 75/1000 iterations complete
# 80/1000 iterations complete
# 85/1000 iterations complete
# 90/1000 iterations complete
# 95/1000 iterations complete
# 100/1000 iterations complete
# 105/1000 iterations complete
# 110/1000 iterations complete
# 115/1000 iterations complete
# 120/1000 iterations complete
# 125/1000 iterations complete
# 130/1000 iterations complete
# 135/1000 iterations complete
# 140/1000 iterations complete
# 145/1000 iterations complete
# 150/1000 iterations complete
# 155/1000 iterations complete
# 160/1000 iterations complete
# 165/1000 iterations complete
# 170/1000 iterations complete
# 175/1000 iterations complete
# 180/1000 iterations complete
# 185/1000 iterations complete
# 190/1000 iterations complete
# 195/1000 iterations complete
# 200/1000 iterations complete
# 205/1000 iterations complete
# 210/1000 iterations complete
# 215/1000 iterations complete
# 220/1000 iterations complete
# 225/1000 iterations complete
# 230/1000 iterations complete
# 235/1000 iterations complete
# 240/1000 iterations complete
# 245/1000 iterations complete
# 250/1000 iterations complete
# 255/1000 iterations complete
# 260/1000 iterations complete
# 265/1000 iterations complete
# 270/1000 iterations complete
# 275/1000 iterations complete
# 280/1000 iterations complete
# 285/1000 iterations complete
# 290/1000 iterations complete
# 295/1000 iterations complete
# 300/1000 iterations complete
# 305/1000 iterations complete
# 310/1000 iterations complete
# 315/1000 iterations complete
# 320/1000 iterations complete
# 325/1000 iterations complete
# 330/1000 iterations complete
# 335/1000 iterations complete
# 340/1000 iterations complete
# 345/1000 iterations complete
# 350/1000 iterations complete
# 355/1000 iterations complete
# 360/1000 iterations complete
# 365/1000 iterations complete
# 370/1000 iterations complete
# 375/1000 iterations complete
# 380/1000 iterations complete
# 385/1000 iterations complete
# 390/1000 iterations complete
# 395/1000 iterations complete
# 400/1000 iterations complete
# 405/1000 iterations complete
# 410/1000 iterations complete
# 415/1000 iterations complete
# 420/1000 iterations complete
# 425/1000 iterations complete
# 430/1000 iterations complete
# 435/1000 iterations complete
# 440/1000 iterations complete
# 445/1000 iterations complete
# 450/1000 iterations complete
# 455/1000 iterations complete
# 460/1000 iterations complete
# 465/1000 iterations complete
# 470/1000 iterations complete
# 475/1000 iterations complete
# 480/1000 iterations complete
# 485/1000 iterations complete
# 490/1000 iterations complete
# 495/1000 iterations complete
# 500/1000 iterations complete
# 505/1000 iterations complete
# 510/1000 iterations complete
# 515/1000 iterations complete
# 520/1000 iterations complete
# 525/1000 iterations complete
# 530/1000 iterations complete
# 535/1000 iterations complete
# 540/1000 iterations complete
# 545/1000 iterations complete
# 550/1000 iterations complete
# 555/1000 iterations complete
# 560/1000 iterations complete
# 565/1000 iterations complete
# 570/1000 iterations complete
# 575/1000 iterations complete
# 580/1000 iterations complete
# 585/1000 iterations complete
# 590/1000 iterations complete
# 595/1000 iterations complete
# 600/1000 iterations complete
# 605/1000 iterations complete
# 610/1000 iterations complete
# 615/1000 iterations complete
# 620/1000 iterations complete
# 625/1000 iterations complete
# 630/1000 iterations complete
# 635/1000 iterations complete
# 640/1000 iterations complete
# 645/1000 iterations complete
# 650/1000 iterations complete
# 655/1000 iterations complete
# 660/1000 iterations complete
# 665/1000 iterations complete
# 670/1000 iterations complete
# 675/1000 iterations complete
# 680/1000 iterations complete
# 685/1000 iterations complete
# 690/1000 iterations complete
# 695/1000 iterations complete
# 700/1000 iterations complete
# 705/1000 iterations complete
# 710/1000 iterations complete
# 715/1000 iterations complete
# 720/1000 iterations complete
# 725/1000 iterations complete
# 730/1000 iterations complete
# 735/1000 iterations complete
# 740/1000 iterations complete
# 745/1000 iterations complete
# 750/1000 iterations complete
# 755/1000 iterations complete
# 760/1000 iterations complete
# 765/1000 iterations complete
# 770/1000 iterations complete
# 775/1000 iterations complete
# 780/1000 iterations complete
# 785/1000 iterations complete
# 790/1000 iterations complete
# 795/1000 iterations complete
# 800/1000 iterations complete
# 805/1000 iterations complete
# 810/1000 iterations complete
# 815/1000 iterations complete
# 820/1000 iterations complete
# 825/1000 iterations complete
# 830/1000 iterations complete
# 835/1000 iterations complete
# 840/1000 iterations complete
# 845/1000 iterations complete
# 850/1000 iterations complete
# 855/1000 iterations complete
# 860/1000 iterations complete
# 865/1000 iterations complete
# 870/1000 iterations complete
# 875/1000 iterations complete
# 880/1000 iterations complete
# 885/1000 iterations complete
# 890/1000 iterations complete
# 895/1000 iterations complete
# 900/1000 iterations complete
# 905/1000 iterations complete
# 910/1000 iterations complete
# 915/1000 iterations complete
# 920/1000 iterations complete
# 925/1000 iterations complete
# 930/1000 iterations complete
# 935/1000 iterations complete
# 940/1000 iterations complete
# 945/1000 iterations complete
# 950/1000 iterations complete
# 955/1000 iterations complete
# 960/1000 iterations complete
# 965/1000 iterations complete
# 970/1000 iterations complete
# 975/1000 iterations complete
# 980/1000 iterations complete
# 985/1000 iterations complete
# 990/1000 iterations complete
# 995/1000 iterations complete
# 1000/1000 iterations complete

# %%
for i in range(0,v.shape[1]):
    base = v[:,i].A1
    n_top_words = 10
    name =  " ".join([tfidf_feature_names[j] for j in base.argsort()[:-n_top_words - 1:-1]])
    print name
# Out:
# banks abs loans collateral bank lending economic ecb said small
# watt freddie mae fannie mac senate republican nomination panel committee
# truth opinions reason certain nature objects true men god thought
# invasion allied troops normandy german british germans landing beaches france
# report exchanges hhs consumers plans cost health costs premiums healthcare
# jays blue toronto hit rockies run bautista game said johnson
# reds cincinnati pirates hit season cueto latos pittsburgh game bruce
# twins minnesota runs game said innings inning indians run plouffe
# rays jays blue tampa toronto bay reyes myers dickey gibbons
# percent revenue quarter billion million company share cents year sales

# %%
#lambda = 0.2
#truth opinions reason certain nature objects true men god thought
#pirates reds cincinnati pittsburgh hit alvarez latos season left inning
#percent revenue quarter billion million company share cents year sales
#watt mae freddie fannie mac senate republican nomination panel committee
#cueto reds arizona run corbin kubel diamondbacks cincinnati bruce hit
#twins minnesota runs game said innings inning indians plouffe hit
#report exchanges hhs consumers plans cost health costs premiums healthcare
#invasion allied troops normandy german british germans landing beaches france
#banks abs loans collateral bank lending economic ecb said small
#jays blue toronto hit game said gibbons run bautista rockie#s

# %%
#lambda = 2
#banks abs loans collateral bank lending economic ecb said small
#watt freddie mae fannie mac senate republican nomination panel committee
#truth opinions reason certain nature objects true men god thought
#invasion allied troops normandy german british germans landing beaches france
#report exchanges hhs consumers plans cost health costs premiums healthcare
#jays blue toronto hit rockies run bautista game said johnson
#reds cincinnati pirates hit season cueto latos pittsburgh game bruce
#twins minnesota runs game said innings inning indians run plouffe
#rays jays blue tampa toronto bay reyes myers dickey gibbons
#percent revenue quarter billion million company share cents year sales
